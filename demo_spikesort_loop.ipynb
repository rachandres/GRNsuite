# %% [markdown]
# ## Spikesorting loop through all data
#
# This demo shows how to loop through all data in a directory and apply the spike sorting pipeline to each file.

# %%
import grnsuite.spike_detection as spikes
import grnsuite.spike_sorting as sorting
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
import numpy as np
import os
import glob

matplotlib.use("TkAgg")  # Set the backend before creating any figures

# %%
def process_file(results_dir):
    """Process a single file and show figures"""
    print(f"\nProcessing {os.path.basename(results_dir)}...")
    
    # Load data
    waveforms = pd.read_csv(os.path.join(results_dir, 'waveforms.csv')).values
    spikes_df = pd.read_csv(os.path.join(results_dir, 'detected_spikes.csv'))
    processed_data = pd.read_csv(os.path.join(results_dir, 'processed_data.csv'))
    
    # Reduce dimensions and cluster
    reduced_waveforms = sorting.reduce_dimensions(waveforms, n_components=3)
    n_clusters = sorting.estimate_clusters(reduced_waveforms)
    labels = sorting.cluster_spikes(reduced_waveforms, n_clusters=n_clusters)
    
    # Create unit labels
    unit_labels = [f'unit_{label + 1}' for label in labels]
    spikes_df['unit'] = unit_labels
    
    # Save sorted spikes
    spikes_df.to_csv(os.path.join(results_dir, 'sorted_spikes.csv'), index=False)
    
    # create figure with 3 panels showing clustering:
    sorting.plot_clustering_summary(
        waveforms, 
        reduced_waveforms, 
        labels,
        save_path=os.path.join(results_dir, 'clustering_summary.png')
    )

    # Create second figure for time series
    sorting.plot_sorted_spikes(
        processed_data,
        spikes_df,
        save_path=os.path.join(results_dir, 'sorted_spikes.png')
    )
    # Print statistics
    print("\nUnit Statistics:")
    for unit in unique_units:
        count = len(spikes_df[spikes_df['unit'] == unit])
        print(f"{unit}: {count} spikes")

# Get all result directories and process each one
base_dir = "results"
result_dirs = glob.glob(os.path.join(base_dir, "*"))

for results_dir in result_dirs:
    try:
        process_file(results_dir)
    except Exception as e:
        print(f"Error processing {results_dir}: {str(e)}")
        continue
# Out:
# Processing 20231103-M04-sucr-100-Gal-A1-02...
# Explained variance with 3 components: 98.37%
# Clusters: 2, Silhouette Score: 0.245
# Clusters: 3, Silhouette Score: 0.594
# Clusters: 4, Silhouette Score: 0.263
# Clusters: 5, Silhouette Score: 0.388
# Clusters: 6, Silhouette Score: 0.266
# Clusters: 7, Silhouette Score: 0.255
# Clusters: 8, Silhouette Score: 0.257
# Clusters: 9, Silhouette Score: 0.256
# Clusters: 10, Silhouette Score: 0.266
#
# Optimal number of clusters: 3
# Cluster 0 size: 179
# Cluster 1 size: 16
# Cluster 2 size: 13
# Error processing results\20231103-M04-sucr-100-Gal-A1-02: module 'grnsuite.spike_sorting' has no attribute 'plot_clustering_summary'
#
# Processing 20231103-M04-sucr-100-Gal-A2-02...
# Explained variance with 3 components: 98.66%
# Clusters: 2, Silhouette Score: 0.401
# Clusters: 3, Silhouette Score: 0.396
# Clusters: 4, Silhouette Score: 0.286
# Clusters: 5, Silhouette Score: 0.292
# Clusters: 6, Silhouette Score: 0.277
# Clusters: 7, Silhouette Score: 0.268
# Clusters: 8, Silhouette Score: 0.237
# Clusters: 9, Silhouette Score: 0.237
# Clusters: 10, Silhouette Score: 0.250
#
# Optimal number of clusters: 2
# Cluster 0 size: 111
# Cluster 1 size: 193
# Error processing results\20231103-M04-sucr-100-Gal-A2-02: module 'grnsuite.spike_sorting' has no attribute 'plot_clustering_summary'
#
# Processing 20231103-M05-sucr-100-Gal-A1-02...
# Explained variance with 3 components: 98.49%
# Clusters: 2, Silhouette Score: 0.410
# Clusters: 3, Silhouette Score: 0.442
# Clusters: 4, Silhouette Score: 0.348
# Clusters: 5, Silhouette Score: 0.268
# Clusters: 6, Silhouette Score: 0.265
# Clusters: 7, Silhouette Score: 0.272
# Clusters: 8, Silhouette Score: 0.247
# Clusters: 9, Silhouette Score: 0.249
# Clusters: 10, Silhouette Score: 0.247
#
# Optimal number of clusters: 3
# Cluster 0 size: 52
# Cluster 1 size: 156
# Cluster 2 size: 7
# Error processing results\20231103-M05-sucr-100-Gal-A1-02: module 'grnsuite.spike_sorting' has no attribute 'plot_clustering_summary'
#
# Processing 20231103-M05-sucr-100-Gal-A2-01...
# Explained variance with 3 components: 98.94%
# Clusters: 2, Silhouette Score: 0.544
# Clusters: 3, Silhouette Score: 0.309
# Clusters: 4, Silhouette Score: 0.232
# Clusters: 5, Silhouette Score: 0.261
# Clusters: 6, Silhouette Score: 0.278
# Clusters: 7, Silhouette Score: 0.276
# Clusters: 8, Silhouette Score: 0.260
# Clusters: 9, Silhouette Score: 0.253
# Clusters: 10, Silhouette Score: 0.223
#
# Optimal number of clusters: 2
# Cluster 0 size: 22
# Cluster 1 size: 178
# Error processing results\20231103-M05-sucr-100-Gal-A2-01: module 'grnsuite.spike_sorting' has no attribute 'plot_clustering_summary'
#
# Processing 20231103-M05-sucr-100-Gal-A3-02...
# Explained variance with 3 components: 99.19%
# Clusters: 2, Silhouette Score: 0.570
# Clusters: 3, Silhouette Score: 0.485
# Clusters: 4, Silhouette Score: 0.490
# Clusters: 5, Silhouette Score: 0.275
# Clusters: 6, Silhouette Score: 0.278
# Clusters: 7, Silhouette Score: 0.268
# Clusters: 8, Silhouette Score: 0.298
# Clusters: 9, Silhouette Score: 0.286
# Clusters: 10, Silhouette Score: 0.284
#
# Optimal number of clusters: 2
# Cluster 0 size: 134
# Cluster 1 size: 29
# Error processing results\20231103-M05-sucr-100-Gal-A3-02: module 'grnsuite.spike_sorting' has no attribute 'plot_clustering_summary'
#
# Processing 20231106-F02-sucr-100-Gal-A2-02...
# Explained variance with 3 components: 97.98%
# Clusters: 2, Silhouette Score: 0.452
# Clusters: 3, Silhouette Score: 0.345
# Clusters: 4, Silhouette Score: 0.319
# Clusters: 5, Silhouette Score: 0.249
# Clusters: 6, Silhouette Score: 0.242
# Clusters: 7, Silhouette Score: 0.248
# Clusters: 8, Silhouette Score: 0.323
# Clusters: 9, Silhouette Score: 0.276
# Clusters: 10, Silhouette Score: 0.278
#
# Optimal number of clusters: 2
# Cluster 0 size: 145
# Cluster 1 size: 38
# Error processing results\20231106-F02-sucr-100-Gal-A2-02: module 'grnsuite.spike_sorting' has no attribute 'plot_clustering_summary'
#
# Processing 20231106-F02-sucr-100-Gal-A3-02...
# Explained variance with 3 components: 98.20%
# Clusters: 2, Silhouette Score: 0.591
# Clusters: 3, Silhouette Score: 0.381
# Clusters: 4, Silhouette Score: 0.391
# Clusters: 5, Silhouette Score: 0.375
# Clusters: 6, Silhouette Score: 0.306
# Clusters: 7, Silhouette Score: 0.309
# Clusters: 8, Silhouette Score: 0.260
# Clusters: 9, Silhouette Score: 0.277
# Clusters: 10, Silhouette Score: 0.284
#
# Optimal number of clusters: 2
# Cluster 0 size: 159
# Cluster 1 size: 51
# Error processing results\20231106-F02-sucr-100-Gal-A3-02: module 'grnsuite.spike_sorting' has no attribute 'plot_clustering_summary'
#
# Processing 20231106-M01-sucr-100-Gal-A1-02...
# Explained variance with 3 components: 99.29%
# Clusters: 2, Silhouette Score: 0.529
# Clusters: 3, Silhouette Score: 0.531
# Clusters: 4, Silhouette Score: 0.365
# Clusters: 5, Silhouette Score: 0.377
# Clusters: 6, Silhouette Score: 0.304
# Clusters: 7, Silhouette Score: 0.305
# Clusters: 8, Silhouette Score: 0.275
# Clusters: 9, Silhouette Score: 0.258
# Clusters: 10, Silhouette Score: 0.241
#
# Optimal number of clusters: 3
# Cluster 0 size: 173
# Cluster 1 size: 30
# Cluster 2 size: 3
# Error processing results\20231106-M01-sucr-100-Gal-A1-02: module 'grnsuite.spike_sorting' has no attribute 'plot_clustering_summary'
#
# Processing 20231106-M01-sucr-100-Gal-A2-02...
# Explained variance with 3 components: 98.53%
# Clusters: 2, Silhouette Score: 0.591
# Clusters: 3, Silhouette Score: 0.418
# Clusters: 4, Silhouette Score: 0.273
# Clusters: 5, Silhouette Score: 0.262
# Clusters: 6, Silhouette Score: 0.261
# Clusters: 7, Silhouette Score: 0.277
# Clusters: 8, Silhouette Score: 0.282
# Clusters: 9, Silhouette Score: 0.270
# Clusters: 10, Silhouette Score: 0.260
#
# Optimal number of clusters: 2
# Cluster 0 size: 208
# Cluster 1 size: 11
# Error processing results\20231106-M01-sucr-100-Gal-A2-02: module 'grnsuite.spike_sorting' has no attribute 'plot_clustering_summary'
