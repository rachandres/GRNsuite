# %% [markdown]
# ## Spikesorting loop through all data
#
# This demo shows how to loop through all data in a directory and apply the spike sorting pipeline to each file.

# %%
import grnsuite.spike_detection as spikes
import grnsuite.spike_sorting as sorting
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
import numpy as np
import os
import glob

matplotlib.use("TkAgg")  # Set the backend before creating any figures

# %%
def process_file(results_dir):
    """Process a single file and show figures"""
    print(f"\nProcessing {os.path.basename(results_dir)}...")
    
    # Load data
    waveforms = pd.read_csv(os.path.join(results_dir, 'waveforms.csv')).values
    spikes_df = pd.read_csv(os.path.join(results_dir, 'detected_spikes.csv'))
    processed_data = pd.read_csv(os.path.join(results_dir, 'processed_data.csv'))
    
    # Reduce dimensions and cluster
    reduced_waveforms = sorting.reduce_dimensions(waveforms, n_components=3)
    n_clusters = sorting.estimate_clusters(reduced_waveforms)
    labels = sorting.cluster_spikes(reduced_waveforms, n_clusters=n_clusters)
    
    # Create unit labels
    unit_labels = [f'unit_{label + 1}' for label in labels]
    spikes_df['unit'] = unit_labels
    
    # Save sorted spikes
    spikes_df.to_csv(os.path.join(results_dir, 'sorted_spikes.csv'), index=False)
    
    # create figure with 3 panels showing clustering:
    sorting.plot_clustering_summary(
        waveforms, 
        reduced_waveforms, 
        labels,
        save_path=os.path.join(results_dir, 'clustering_summary.png')
    )

    # Create second figure for time series
    sorting.plot_sorted_spikes(
        processed_data,
        spikes_df,
        save_path=os.path.join(results_dir, 'sorted_spikes.png')
    )
    # Print statistics
    print("\nUnit Statistics:")
    for unit in unique_units:
        count = len(spikes_df[spikes_df['unit'] == unit])
        print(f"{unit}: {count} spikes")

# Get all result directories and process each one
base_dir = "results"
result_dirs = glob.glob(os.path.join(base_dir, "*"))

for results_dir in result_dirs:
    try:
        process_file(results_dir)
    except Exception as e:
        print(f"Error processing {results_dir}: {str(e)}")
        continue
# Out:
# Processing 20231103-M04-sucr-100-Gal-A1-02...
# Explained variance with 3 components: 87.09%
# Clusters: 2, Silhouette Score: 0.644
# Clusters: 3, Silhouette Score: 0.613
# Clusters: 4, Silhouette Score: 0.392
# Clusters: 5, Silhouette Score: 0.258
# Clusters: 6, Silhouette Score: 0.262
# Clusters: 7, Silhouette Score: 0.267
# Clusters: 8, Silhouette Score: 0.248
# Clusters: 9, Silhouette Score: 0.246
# Clusters: 10, Silhouette Score: 0.221
#
# Optimal number of clusters: 2
# Cluster 0 size: 190
# Cluster 1 size: 16
#
# Unit Statistics:
# Error processing results/20231103-M04-sucr-100-Gal-A1-02: name 'unique_units' is not defined
#
# Processing 20231106-M01-sucr-100-Gal-A1-02...
# Explained variance with 3 components: 92.76%
# Clusters: 2, Silhouette Score: 0.471
# Clusters: 3, Silhouette Score: 0.452
# Clusters: 4, Silhouette Score: 0.208
# Clusters: 5, Silhouette Score: 0.215
# Clusters: 6, Silhouette Score: 0.279
# Clusters: 7, Silhouette Score: 0.205
# Clusters: 8, Silhouette Score: 0.246
# Clusters: 9, Silhouette Score: 0.228
# Clusters: 10, Silhouette Score: 0.230
#
# Optimal number of clusters: 2
# Cluster 0 size: 167
# Cluster 1 size: 32
#
# Unit Statistics:
# Error processing results/20231106-M01-sucr-100-Gal-A1-02: name 'unique_units' is not defined
#
# Processing 20231103-M05-sucr-100-Gal-A3-02...
# Explained variance with 3 components: 91.99%
# Clusters: 2, Silhouette Score: 0.591
# Clusters: 3, Silhouette Score: 0.497
# Clusters: 4, Silhouette Score: 0.524
# Clusters: 5, Silhouette Score: 0.270
# Clusters: 6, Silhouette Score: 0.283
# Clusters: 7, Silhouette Score: 0.296
# Clusters: 8, Silhouette Score: 0.269
# Clusters: 9, Silhouette Score: 0.274
# Clusters: 10, Silhouette Score: 0.322
#
# Optimal number of clusters: 2
# Cluster 0 size: 22
# Cluster 1 size: 135
#
# Unit Statistics:
# Error processing results/20231103-M05-sucr-100-Gal-A3-02: name 'unique_units' is not defined
#
# Processing 20231103-M04-sucr-100-Gal-A2-02...
# Explained variance with 3 components: 92.78%
# Clusters: 2, Silhouette Score: 0.438
# Clusters: 3, Silhouette Score: 0.439
# Clusters: 4, Silhouette Score: 0.411
# Clusters: 5, Silhouette Score: 0.360
# Clusters: 6, Silhouette Score: 0.364
# Clusters: 7, Silhouette Score: 0.360
# Clusters: 8, Silhouette Score: 0.261
# Clusters: 9, Silhouette Score: 0.258
# Clusters: 10, Silhouette Score: 0.266
#
# Optimal number of clusters: 3
# Cluster 0 size: 97
# Cluster 1 size: 196
# Cluster 2 size: 10
#
# Unit Statistics:
# Error processing results/20231103-M04-sucr-100-Gal-A2-02: name 'unique_units' is not defined
#
# Processing 20231103-M05-sucr-100-Gal-A1-02...
# Explained variance with 3 components: 85.25%
# Clusters: 2, Silhouette Score: 0.327
# Clusters: 3, Silhouette Score: 0.254
# Clusters: 4, Silhouette Score: 0.262
# Clusters: 5, Silhouette Score: 0.246
# Clusters: 6, Silhouette Score: 0.251
# Clusters: 7, Silhouette Score: 0.267
# Clusters: 8, Silhouette Score: 0.248
# Clusters: 9, Silhouette Score: 0.254
# Clusters: 10, Silhouette Score: 0.275
#
# Optimal number of clusters: 2
# Cluster 0 size: 70
# Cluster 1 size: 142
#
# Unit Statistics:
# Error processing results/20231103-M05-sucr-100-Gal-A1-02: name 'unique_units' is not defined
#
# Processing 20231106-M01-sucr-100-Gal-A2-02...
# Explained variance with 3 components: 89.14%
# Clusters: 2, Silhouette Score: 0.353
# Clusters: 3, Silhouette Score: 0.313
# Clusters: 4, Silhouette Score: 0.233
# Clusters: 5, Silhouette Score: 0.238
# Clusters: 6, Silhouette Score: 0.244
# Clusters: 7, Silhouette Score: 0.254
# Clusters: 8, Silhouette Score: 0.243
# Clusters: 9, Silhouette Score: 0.237
# Clusters: 10, Silhouette Score: 0.235
#
# Optimal number of clusters: 2
# Cluster 0 size: 143
# Cluster 1 size: 70
#
# Unit Statistics:
# Error processing results/20231106-M01-sucr-100-Gal-A2-02: name 'unique_units' is not defined
#
# Processing 20231103-M05-sucr-100-Gal-A2-01...
# Explained variance with 3 components: 88.54%
# Clusters: 2, Silhouette Score: 0.215
# Clusters: 3, Silhouette Score: 0.229
# Clusters: 4, Silhouette Score: 0.334
# Clusters: 5, Silhouette Score: 0.352
# Clusters: 6, Silhouette Score: 0.388
# Clusters: 7, Silhouette Score: 0.270
# Clusters: 8, Silhouette Score: 0.272
# Clusters: 9, Silhouette Score: 0.272
# Clusters: 10, Silhouette Score: 0.258
#
# Optimal number of clusters: 6
# Cluster 0 size: 130
# Cluster 1 size: 18
# Cluster 2 size: 4
# Cluster 3 size: 39
# Cluster 4 size: 2
# Cluster 5 size: 9
#
# Unit Statistics:
# Error processing results/20231103-M05-sucr-100-Gal-A2-01: name 'unique_units' is not defined
#
# Processing 20231106-F02-sucr-100-Gal-A2-02...
# Explained variance with 3 components: 84.87%
# Clusters: 2, Silhouette Score: 0.458
# Clusters: 3, Silhouette Score: 0.280
# Clusters: 4, Silhouette Score: 0.307
# Clusters: 5, Silhouette Score: 0.207
# Clusters: 6, Silhouette Score: 0.246
# Clusters: 7, Silhouette Score: 0.241
# Clusters: 8, Silhouette Score: 0.246
# Clusters: 9, Silhouette Score: 0.245
# Clusters: 10, Silhouette Score: 0.264
#
# Optimal number of clusters: 2
# Cluster 0 size: 30
# Cluster 1 size: 147
#
# Unit Statistics:
# Error processing results/20231106-F02-sucr-100-Gal-A2-02: name 'unique_units' is not defined
#
# Processing 20231106-F02-sucr-100-Gal-A3-02...
# Explained variance with 3 components: 85.84%
# Clusters: 2, Silhouette Score: 0.515
# Clusters: 3, Silhouette Score: 0.519
# Clusters: 4, Silhouette Score: 0.396
# Clusters: 5, Silhouette Score: 0.305
# Clusters: 6, Silhouette Score: 0.271
# Clusters: 7, Silhouette Score: 0.265
# Clusters: 8, Silhouette Score: 0.293
# Clusters: 9, Silhouette Score: 0.290
# Clusters: 10, Silhouette Score: 0.311
#
# Optimal number of clusters: 3
# Cluster 0 size: 65
# Cluster 1 size: 50
# Cluster 2 size: 2
#
# Unit Statistics:
# Error processing results/20231106-F02-sucr-100-Gal-A3-02: name 'unique_units' is not defined
